# %%
import numpy
import matplotlib.pyplot as plt
a = attn_output_weights[0]
a = a.data.cpu().numpy()
numpy.save("./debug_figure/decoder/decoderlayer3_transformer_emb_MHA.npy", a)
map = numpy.load("./debug_figure/decoder/decoderlayer3_transformer_emb_MHA.npy")
plt.imshow(map)
plt.savefig("./debug_figure/decoder/decoderlayer3_transformer_emb_MHA.png")
